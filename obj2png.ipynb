# %%
# !python .\src\obj2png.py -i .\obj\first.obj -a -95 -e 100
# Out:
# Namespace(objfiles=['.\\obj\\first.obj'], outfile=None, azim=-95.0, elevation=100.0, quality=None, resolution=None, scale=None, view=False, animate=False)
# ДАЛЕЕ
# Converting .\obj\first.obj to .\obj\first.png

# %%
# !python .\src\obj2png.py --help
# Out:
# usage: obj2png.py [-h] [-i OBJFILES [OBJFILES ...]] [-o OUTFILE] [-a AZIM]
#                   [-e ELEVATION] [-q QUALITY] [--resolution RESOLUTION]
#                   [-s SCALE] [-v] [-A]
#
# Obj to png using MatPlotLib
#
# options:
#   -h, --help            show this help message and exit
#   -i OBJFILES [OBJFILES ...], --infiles OBJFILES [OBJFILES ...]
#                         File or files to be converted to png
#   -o OUTFILE, --outfile OUTFILE
#                         Output file(s). Default: infile.png
#   -a AZIM, --azimuth AZIM
#                         Azimuth angle of view in degrees.
#   -e ELEVATION, --elevation ELEVATION
#                         Elevation angle of view in degrees.
#   -q QUALITY, --quality QUALITY
#                         Image quality (HIGH,MEDIUM,LOW). Default: LOW
#   --resolution RESOLUTION
#                         Image resolution, takes precedence over quality
#                         argument. For example 640x480
#   -s SCALE, --scale SCALE
#                         Scale picture by descreasing boundaries. Lower than 1.
#                         gives a larger object.
#   -v, --view            View instead of creating picture file.
#   -A, --Animate         Animate instead of creating picture file as animation,
#                         from elevation -180:180 and azim -180:180

# %% [markdown]
# ## Запуск генерации для одного файла
# файл Болт с гайкой
# "C:\Users\eddyd\Downloads\Praktikum\Chackaton_HB\obj2png\obj\screw.obj"

# %% [markdown]
# Выводим одну картинку в файл
# в папку
# png\screw
#
# здесь папка png общая для всех
# а папка screw - по имени 3д файла

# %% [markdown]
# ### параметры вызова команды
# * !python .\src\obj2png.py ** вызов программного файла из папки следующего уровня
# * -i .\obj\screw.obj ** вызов 3д файла из папки следующего уровня
# * -o .\png\screw\00000.png ** задаём имя выходного файла
# * -a 45 ** угол обзора в градусах  от -180 до 180
# * -e 45 ** угол обзора по высоте  от -180 до 180
# * -q HIGH ** качество прорисовки картинки (HIGH,MEDIUM,LOW)
# * --resolution 300x300 ** разрешение картинки
# * ** -s 2 ** масштабирование картинки для уменьшения границ

# %%
# !python .\src\obj2png.py -i .\obj\screw.obj -o .\png\screw\00000.png -a 180 -e 45 -q HIGH --resolution 300x300 -s 1
# Out:
# Namespace(objfiles=['.\\obj\\screw.obj'], outfile='.\\png\\screw\\00000.png', azim=-180.0, elevation=45.0, quality='HIGH', resolution='300x300', scale=1.0, view=False, animate=False)
# ДАЛЕЕ
# Converting .\obj\screw.obj to .\png\screw\00000.png

# %%
a_angle = 45
v_angle = 90
output = ".\\png\\screw\\" + str(a_angle) + str(v_angle) + ".png"
output
# Out:
# '.\\png\\screw\\4590.png'

# %%
# !python .\src\obj2png.py -i .\obj\screw.obj -o {output} -a 45 -e 45 -q HIGH --resolution 300x300 -s 1
# Out:
# Namespace(objfiles=['.\\obj\\screw.obj'], outfile='.\\png\\screw\\4590.png', azim=45.0, elevation=45.0, quality='HIGH', resolution='300x300', scale=1.0, view=False, animate=False)
# ДАЛЕЕ
# Converting .\obj\screw.obj to .\png\screw\4590.png

# %% [markdown]
# ### делаем миллион картинок одной 3д модельки
# * меняем переменную a_angle от -180 до 180 с шагом 5
# * меняем переменную v_angle от -180 до 180 с шагом 5
# * формируем название файла '".\png\screw\" + str(a_angle) + str(v_angle) + ".png"'

# %%
a_angle = 45
v_angle = 90
output = ".\\png\\screw\\" + str(a_angle) + str(v_angle) + ".png"
output
# Out:
# '.\\png\\screw\\4590.png'

# %%
for a_angle in range(-180, 185, 5): 
    for v_angle in range(-180, 185, 5): 
        output = ".\\png\\screw\\" + str(a_angle) + "r" + str(v_angle) + ".png"
        # !python .\src\obj2png.py -i .\obj\screw.obj -o  {output} -a {a_angle} -e {v_angle} -q HIGH --resolution 300x300 -s 1
# Out:
# Namespace(objfiles=['.\\obj\\screw.obj'], outfile='.\\png\\screw\\-180r